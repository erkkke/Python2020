# %% [markdown]
# # Homework (5 points, Deadline 18.04.2020)

# %% [markdown]
# 1_mpg - датасет, в котором содержатся данные о машине:
# ![IMAGE%202020-04-04%2014:05:33.jpg](attachment:IMAGE%202020-04-04%2014:05:33.jpg)

# %% [markdown]
# 2_real_estate - датасет, в котором содержатся данные о домах:
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-04-04%20%D0%B2%2014.05.25.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-04-04%20%D0%B2%2014.05.25.png)

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-04-04%20%D0%B2%2013.49.15.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-04-04%20%D0%B2%2013.49.15.png)

# %% [markdown]
# # Задание

# %% [markdown]
# 1. Нужно провести Explanatory data analysis вашего датасета, то есть анализируете какие у вас есть данные, строите графики, boxplots, описываете свои переменные).
# 2. Нужно построить 1 Simple linear regression model (сами смотрите взаимосвязь между какими переменными хотите рассмотреть). Интерпретировать все коэффициенты обязательно также, как разбирали на уроках.
# 3. Нужно построить 1 Miltuvariate linear regression model.Интерпретировать все коэффициенты обязательно также, как разбирали на уроках.

# %% [markdown]
# # Важно!
# Сдаете мне не код, а word-овский файл с вашим анализом. То есть описываете какую взаимосвязь вы хотели проверить, прикладываете графики, описываете переменные, которые взяли, описываете коэффициенты, которые получились. В конце обязательно написать вывод, который вы сделали после своего анализа.

# %% [markdown]
# # Deadline: 14.04.2020. Фомат: сдаете два файла: код (можно Excel, если там высчитываете коэффициенты и строите графики) и Word-овский файл с анализом.

# %% [markdown]
#  Задачи:

# %% [markdown]
# # Simple linear regression

# %% [markdown]
# ![IMAGE%202020-04-04%2014:25:24.jpg](attachment:IMAGE%202020-04-04%2014:25:24.jpg)

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
from scipy.stats import linregress
from scipy import stats

# %% [markdown]
# Q1: Crickets make their chirping sound by sliding one wing cover very rapidly back and forth over the other. Biologists have long been aware that there is a linear re- lationship between temperature and the frequency with which a cricket chirps, although the slope and y-intercept of the relationship vary from species to species. The following table lists fifteen frequency-temperature obser- vations recorded for the striped ground cricket, Nemobius fasciatus fasciatus (145). Plot these data and find the equa- tion of the least squares line, y = a + bx. Suppose a cricket of this species is observed to chirp eighteen times per second. What would be the estimated temperature?
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-04-04%20%D0%B2%2014.24.02.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-04-04%20%D0%B2%2014.24.02.png)

# %%
df = {'chirps_per_second': [20.0, 16.0, 19.8, 18.4, 17.1, 15.5, 14.7, 17.1, 15.4, 16.2, 15.0, 17.2, 16.0, 17.0, 14.4],
            'temperature': [88.6, 71.6, 93.3, 84.3, 80.6, 75.2, 69.4, 82.0, 69.4, 83.3, 79.6, 82.6, 80.6, 83.5, 76.3]}

# %%
data = pd.DataFrame(data=df)
data
# Out:
#     chirps_per_second  temperature
# 0                20.0         88.6
# 1                16.0         71.6
# 2                19.8         93.3
# 3                18.4         84.3
# 4                17.1         80.6
# 5                15.5         75.2
# 6                14.7         69.4
# 7                17.1         82.0
# 8                15.4         69.4
# 9                16.2         83.3
# 10               15.0         79.6
# 11               17.2         82.6
# 12               16.0         80.6
# 13               17.0         83.5
# 14               14.4         76.3

# %%
x = data.chirps_per_second #Independent variable (X) - chirps_per_second
y = data.temperature #Dependent variable (Y) - temperature

# %%
data.plot(x='chirps_per_second', y='temperature', style='o')
plt.title('Chirps per second vs Temperature')
plt.xlabel('Chirps per second')
plt.ylabel('Temperature')
plt.show()

# %% [markdown]
# Найдите slope, intercept.

# %% [markdown]
# Постройте модель простой линейно регрессии:

# %% [markdown]
# Выведите значения y, которые предсказала ваша модель для каждого значения x:

# %% [markdown]
# Выведите значения residuals (разница между реальным значением y и предсказанным y):

# %% [markdown]
# Постройте график residuals:

# %%
plt.xlabel('hours')
plt.ylabel('residual')
plt.scatter(student_data.hours,...,color='red')

# %% [markdown]
# Q2: An Atomic Energy Commission nuclear facility was established in Hanford, Washington, in 1943. Over the years, a significant amount of strontium 90 and cesium 137 leaked into the Columbia River. In a study to deter- mine how much this radioactivity caused serious medical problems for those who lived along the river, public health officials created an index of radioactive exposure for nine Oregon counties in the vicinity of the river. As a covariate, cancer mortality was determined for each of the counties (45). The results are given in the table in the next column. For the nine (xi,yi)’s in the table,
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-04-04%20%D0%B2%2014.36.34.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-04-04%20%D0%B2%2014.36.34.png)
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-04-04%20%D0%B2%2014.36.40.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-04-04%20%D0%B2%2014.36.40.png)

# %% [markdown]
# Используя формулы, постройте уравнение линейной регрессии:

# %% [markdown]
# Постройте график с линейной регрессией и данными:

# %% [markdown]
# # Повторим hypothesis tesing:

# %% [markdown]
# Задача из бонус-домашки:

# %% [markdown]
# Q3:
# ![IMAGE%202020-04-04%2014:48:22.jpg](attachment:IMAGE%202020-04-04%2014:48:22.jpg)

# %% [markdown]
# Q4:
# Вопрос по теории:
#
# Suppose H0 : μ = μ0 is rejected in favor of H1:μ ̸= μ0 at the α = 0.05 level of significance. Would H0 necessarily be rejected at the α = 0.01 level of significance?
# (b) Suppose H0: μ = μ0 is rejected in favor of H1: μ ̸= μ0 at the α = 0.01 level of significance. Would H0 necessarily be rejected at the α = 0.05 level of significance?

# %% [markdown]
# Q5:
# Some states that operate a lottery believe that restricting the use of lottery profits to supporting education makes the lottery more profitable. Other states permit general use of the lottery income. The profitability of the lottery for a group of states in each category is given below.
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-04-04%20%D0%B2%2014.51.45.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-04-04%20%D0%B2%2014.51.45.png)
#
# Test at the α = 0.01 level whether the mean profit of states using the lottery for education is higher than that of states permitting general use. Assume that the variances of the two random variables are equal.

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-04-04%20%D0%B2%2014.40.39.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-04-04%20%D0%B2%2014.40.39.png)

# %% [markdown]
# Q6:
# Insect flight ability can be measured in a laboratory by attaching the insect to a nearly frictionless rotating arm with a thin wire. The “tethered” insect then flies in circles until exhausted. The nonstop distance flown can easily be calculated from the number of revolutions made by the arm. The following are measurements of this sort made on Culex tarsalis mosquitos of four different ages. The response variable is the average distance flown until exhaustion for forty females of the species (159).
# Fit a straight line to these data and test that the slope is zero. Use a two-sided alternative and the 0.05 level of significance.
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-04-04%20%D0%B2%2014.42.30.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-04-04%20%D0%B2%2014.42.30.png)

# %%
data = {'age': [1,2,3,4],
            'distance': [12.6, 11.6, 6.8, 9.2]}

data = pd.DataFrame(data=data)

# %%
x = data.age
y = data.distance

# %%
plt.xlabel('age')
plt.ylabel('distance')
plt.scatter(data.age,data.distance,color='red')

# %%
slope = np.sum((x - np.mean(x))*(y - np.mean(y)))/(np.sum((x-np.mean(x)) ** 2))
slope
# Out:
# -1.5

# %% [markdown]
# # On average, the increase of age by one 1 week, the distance flown decreases by 1.5 thousand meters.

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-04-04%20%D0%B2%2018.29.16.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-04-04%20%D0%B2%2018.29.16.png)

# %% [markdown]
# # Обратите внимание, что тут надо отнимать от y предсказанный y_predicted, а не mean

# %%
st_dev_slope = (np.sqrt(np.sum((y-y_predicted) ** 2)/(n-2)))/(np.sqrt(np.sum((x-np.mean(x)) ** 2)))
st_dev_slope
# Out:
# 0.9455157322858249

# %%
intercept = np.mean(y) - slope*np.mean(x)
intercept
# Out:
# 13.8

# %% [markdown]
# # On average, when the age is 0 week, the distance flown is 13.8 thousand meters.

# %% [markdown]
# Линейная модель:

# %%
def simplelinearmodel(x):
    return intercept+slope*x
y_predicted = simplelinearmodel(x)
y_predicted
# Out:
# 0    12.3
# 1    10.8
# 2     9.3
# 3     7.8
# Name: age, dtype: float64

# %% [markdown]
# # Проверим гипотезу, что возраст насекого влияет на дистанцию, которую оно пролетает. (Ha: slope(age) != 0).

# %%
slope0 = 0
n = 4
df = n - 2  #(потому что теперь 2 параметра: intercept i slope)
a = 0.05
slope = -1.5
st_dev =(np.sqrt(np.sum((y-y_predicted) ** 2)/(n-2)))/(np.sqrt(np.sum((x-np.mean(x)) ** 2)))
st_dev


t_critical = ((slope - slope0)/st_dev)

t_statistic = stats.t.ppf(1-a/2, df) #а делим на 2, потому что two-sided test 

print('t_critical ', t_critical)
print('t_statistic ', t_statistic)
# Out:
# t_critical  -1.5864357924258814
# t_statistic  4.302652729911275

# %% [markdown]
# # At 5% significance level, we do not reject the null hypothesis. There is no evidence that age of the insect affects the distance flown.

# %% [markdown]
# 2-способ:

# %%
age = data.age
distance = data[['distance']]

# %%
import statsmodels.api as sm
age = sm.add_constant(age) # adding an intercept in to model 
 
model = sm.OLS(distance, age).fit()
predictions = model.predict(age) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               distance   R-squared:                       0.557
# Model:                            OLS   Adj. R-squared:                  0.336
# Method:                 Least Squares   F-statistic:                     2.517
# Date:                Sat, 04 Apr 2020   Prob (F-statistic):              0.254
# Time:                        17:57:39   Log-Likelihood:                -7.2842
# No. Observations:                   4   AIC:                             18.57
# Df Residuals:                       2   BIC:                             17.34
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.8000      2.589      5.329      0.033       2.659      24.941
# ...

# %% [markdown]
# Как вы видите, тут уже за вас проверили гипотезу о том, что H0: slope(age) = 0 и Ha: slope(age) !=0. В таблице в колонке 't' стоит значените t-critical -1.586 (по t-таблице получили t-statistic 4.303, что больше нашего t-statistic), что значит что мы не можем отвергнуть нулевую гипотезу.
#
# Также можно сказать по p-value 0.254 больше чем 0.05, что значит что мы не можем отвергнуть нулевую гипотезу.
#
# Вывод на английском должен быть такой: There is no evindence that the age of insect influence on distance flown . At the 5% significance level, we do nor reject the null hypothesis since the p-value is more than 0.05 and t-critical is lower than t-statistic.

# %% [markdown]
# Q7:
#
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-04-04%20%D0%B2%2014.44.14.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202020-04-04%20%D0%B2%2014.44.14.png)
# The best straight line through the Massachusetts funding/graduation rate data has the equation y = 81.088 + 0.412x, where s = 11.78848.
#
# (a) Construct a 95% confidence interval for β1.
#
# (b) What does your answer to part (a) imply about the outcome of testing H0: β1 = 0 versus H1: β1!= 0 at the α = 0.05 level of significance?
#
# (c) Graph the data and superimpose the regression line. How would you summarize these data, and their implica- tions, to a meeting of the state School Board?
